# %% [markdown]
# <a href="https://colab.research.google.com/github/triantonugroho/Applied-Deep-Learning-Task/blob/main/EndTermTask/Generated%20Images/MNIST/EndTermTask_(DCGAN_MNIST).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NAME : TRIANTO HARYO NUGROHO**
#
# **NPM : 2306288931**

# %% [markdown]
# ##1. Import Library

# %%
from keras.models import Sequential
from keras.layers import Dense, Reshape
from tensorflow.keras.layers import Activation, BatchNormalization, UpSampling2D, Dense, Reshape, Conv2D, MaxPooling2D, Flatten
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy as np
from PIL import Image
import argparse
import math

# %% [markdown]
# ##2. Generator Model Function

# %%
def generator_model():
  model = Sequential()
  model.add(Dense(units=1024, input_dim=100))
  model.add(Activation('tanh'))
  model.add(Dense(128*7*7))
  model.add(BatchNormalization())
  model.add(Activation('tanh'))
  model.add(Reshape((7, 7, 128), input_shape=(128*7*7,)))
  model.add(UpSampling2D(size=(2, 2)))
  model.add(Conv2D(64, (5, 5), padding='same'))
  model.add(Activation('tanh'))
  model.add(UpSampling2D(size=(2, 2)))
  model.add(Conv2D(1, (5, 5), padding='same'))
  model.add(Activation('tanh'))
  return model

# %% [markdown]
# ##3. Discriminator Model Function

# %%
def discriminator_model():
  model = Sequential()
  model.add(Conv2D(64, (5, 5), padding='same', input_shape=(28, 28, 1)))
  model.add(Activation('tanh'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(128, (5, 5)))
  model.add(Activation('tanh'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(1024))
  model.add(Activation('tanh'))
  model.add(Dense(1))
  model.add(Activation('sigmoid'))
  return model

# %% [markdown]
# ##4. Generator Containing Discriminator Function

# %%
def generator_containing_discriminator(g, d):
  model = Sequential()
  model.add(g)
  d.trainable = False
  model.add(d)
  return model

# %% [markdown]
# ##5. Combines Image Function

# %%
def combine_images(generated_images):
  num = generated_images.shape[0]
  width = int(math.sqrt(num))
  height = int(math.ceil(float(num)/width))
  shape = generated_images.shape[1:3]
  image = np.zeros((height*shape[0], width*shape[1]), dtype=generated_images.dtype)
  for index, img in enumerate(generated_images):
    i = int(index/width)
    j = index % width
    image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]]= img[:, :, 0]
  return image

# %% [markdown]
# ##6. Training Function

# %%
def train(BATCH_SIZE):
    (X_train, y_train), (X_test, y_test) = mnist.load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)

    # Create discriminator and generator models
    d = discriminator_model()
    g = generator_model()
    d_on_g = generator_containing_discriminator(g, d)

    # Optimizers for generator and discriminator
    d_optim = SGD(learning_rate=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(learning_rate=0.0005, momentum=0.9, nesterov=True)

    g.compile(loss='binary_crossentropy', optimizer=g_optim)
    d.trainable = True
    d.compile(loss='binary_crossentropy', optimizer=d_optim)
    d_on_g.compile(loss='binary_crossentropy', optimizer=g_optim)

    # Training loop
    for epoch in range(20):
        print(f"Epoch is {epoch}")
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            # Generate noise for the generator
            noise = np.random.uniform(-1, 1, size=(BATCH_SIZE, 100))

            # Get a batch of real images
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]

            # Generate images from the noise
            generated_images = g.predict(noise, verbose=0)

            # Save generated images every 20 batches
            if index % 20 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                Image.fromarray(image.astype(np.uint8)).save(f"{epoch}_{index}.png")

            # Train discriminator
            X = np.concatenate((image_batch, generated_images))
            y = np.concatenate((np.ones(BATCH_SIZE), np.zeros(BATCH_SIZE)))
            d_loss = d.train_on_batch(X, y)
            print(f"Batch {index} d_loss: {d_loss}")

            # Train generator
            noise = np.random.uniform(-1, 1, size=(BATCH_SIZE, 100))
            d.trainable = False
            g_loss = d_on_g.train_on_batch(noise, np.ones(BATCH_SIZE))
            d.trainable = True
            print(f"Batch {index} g_loss: {g_loss}")

            # Save weights of generator and discriminator every 10 batches
            if index % 10 == 9:
                g.save_weights('generator.weights.h5')
                d.save_weights('discriminator.weights.h5')

# %% [markdown]
# ##7. Image Generation Function

# %%
def generate(BATCH_SIZE, nice=False):
  g = generator_model()
  g.compile(loss='binary_crossentropy', optimizer="SGD")
  g.load_weights('generator')
  if nice:
    d = discriminator_model()
    d.compile(loss='binary_crossentropy', optimizer="SGD")
    d.load_weights('discriminator')
    noise = np.uniform(-1, 1, (BATCH_SIZE*20, 100))
    generated_images = g.predict(noise, verbose=1)
    d_pred = d.predict(generated_images, verbose=1)
    index = np.arange(0, BATCH_SIZE*20)
    index.resize((BATCH_SIZE*20, 1))
    pre_with_index = list(np.append(d_pred, index, axis=1))
    pre_with_index.sort(key=lambda x: x[0], reverse=True)
    nice_images = np.zeros((BATCH_SIZE,) + generated_images.shape[1:3], dtype=np.float32)
    nice_images = nice_images[:, :, :, None]
    for i in range(BATCH_SIZE):
      idx = int(pre_with_index[1][1])
      nice_images[i, :, :, 0] = generated_images[idx, :, :, 0]
    image = combine_images(nice_images)
  else:
    noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
    generated_images = g.predict(noise, verbose=1)
    image = combine_images(generated_images)
  image = image*127.5+127.5
  Image.fromarray(image.astype(np.uint8)).save("generated_image.png")

# %%
pip install tensorflow keras numpy pillow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)

# %%
# Set BATCH_SIZE and EPOCHS
BATCH_SIZE = 128
EPOCHS = 100

# Train the GAN
train(BATCH_SIZE)

# Generate images after training
generate(BATCH_SIZE, nice=False)  # For raw generated images
generate(BATCH_SIZE, nice=True)   # For discriminator-selected images
# Out:
# Epoch is 0
# Batch 0 d_loss: 0.6954244375228882
# Batch 0 g_loss: [array(0.69542444, dtype=float32), array(0.69542444, dtype=float32), array(0.69542444, dtype=float32)]
# Batch 1 d_loss: 0.6885690689086914
# Batch 1 g_loss: [array(0.68856907, dtype=float32), array(0.68856907, dtype=float32), array(0.68856907, dtype=float32)]
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7a31cb302a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Batch 2 d_loss: 0.6836385726928711
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7a31cb303f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Batch 2 g_loss: [array(0.6836386, dtype=float32), array(0.6836386, dtype=float32), array(0.6836386, dtype=float32)]
# Batch 3 d_loss: 0.6787784695625305
# Batch 3 g_loss: [array(0.67877847, dtype=float32), array(0.67877847, dtype=float32), array(0.67877847, dtype=float32)]
# Batch 4 d_loss: 0.6717756390571594
# Batch 4 g_loss: [array(0.67177564, dtype=float32), array(0.67177564, dtype=float32), array(0.67177564, dtype=float32)]
# Batch 5 d_loss: 0.6640976071357727
# Batch 5 g_loss: [array(0.6640976, dtype=float32), array(0.6640976, dtype=float32), array(0.6640976, dtype=float32)]
# Batch 6 d_loss: 0.6556447744369507
# Batch 6 g_loss: [array(0.6556448, dtype=float32), array(0.6556448, dtype=float32), array(0.6556448, dtype=float32)]
# Batch 7 d_loss: 0.6477659344673157
# Batch 7 g_loss: [array(0.64776593, dtype=float32), array(0.64776593, dtype=float32), array(0.64776593, dtype=float32)]
# Batch 8 d_loss: 0.6398808360099792
# Batch 8 g_loss: [array(0.63988084, dtype=float32), array(0.63988084, dtype=float32), array(0.63988084, dtype=float32)]
# Batch 9 d_loss: 0.6319460868835449
# Batch 9 g_loss: [array(0.6319461, dtype=float32), array(0.6319461, dtype=float32), array(0.6319461, dtype=float32)]
# Batch 10 d_loss: 0.6238248944282532
# Batch 10 g_loss: [array(0.6238249, dtype=float32), array(0.6238249, dtype=float32), array(0.6238249, dtype=float32)]
# Batch 11 d_loss: 0.6160494089126587
# Batch 11 g_loss: [array(0.6160494, dtype=float32), array(0.6160494, dtype=float32), array(0.6160494, dtype=float32)]
# Batch 12 d_loss: 0.6084072589874268
# Batch 12 g_loss: [array(0.60840726, dtype=float32), array(0.60840726, dtype=float32), array(0.60840726, dtype=float32)]
# Batch 13 d_loss: 0.6007925271987915
# Batch 13 g_loss: [array(0.6007925, dtype=float32), array(0.6007925, dtype=float32), array(0.6007925, dtype=float32)]
# Batch 14 d_loss: 0.593858003616333
# Batch 14 g_loss: [array(0.593858, dtype=float32), array(0.593858, dtype=float32), array(0.593858, dtype=float32)]
# Batch 15 d_loss: 0.5872800350189209
# Batch 15 g_loss: [array(0.58728004, dtype=float32), array(0.58728004, dtype=float32), array(0.58728004, dtype=float32)]
# Batch 16 d_loss: 0.580925464630127
# Batch 16 g_loss: [array(0.58092546, dtype=float32), array(0.58092546, dtype=float32), array(0.58092546, dtype=float32)]
# Batch 17 d_loss: 0.5747778415679932
# Batch 17 g_loss: [array(0.57477784, dtype=float32), array(0.57477784, dtype=float32), array(0.57477784, dtype=float32)]
# Batch 18 d_loss: 0.5687737464904785
# Batch 18 g_loss: [array(0.56877375, dtype=float32), array(0.56877375, dtype=float32), array(0.56877375, dtype=float32)]
# Batch 19 d_loss: 0.5633039474487305
# Batch 19 g_loss: [array(0.56330395, dtype=float32), array(0.56330395, dtype=float32), array(0.56330395, dtype=float32)]
# Batch 20 d_loss: 0.5581666231155396
# Batch 20 g_loss: [array(0.5581666, dtype=float32), array(0.5581666, dtype=float32), array(0.5581666, dtype=float32)]
# Batch 21 d_loss: 0.5534129738807678
# Batch 21 g_loss: [array(0.553413, dtype=float32), array(0.553413, dtype=float32), array(0.553413, dtype=float32)]
# Batch 22 d_loss: 0.5491933822631836
# Batch 22 g_loss: [array(0.5491934, dtype=float32), array(0.5491934, dtype=float32), array(0.5491934, dtype=float32)]
# Batch 23 d_loss: 0.544807493686676
# Batch 23 g_loss: [array(0.5448075, dtype=float32), array(0.5448075, dtype=float32), array(0.5448075, dtype=float32)]
# Batch 24 d_loss: 0.540569007396698
# Batch 24 g_loss: [array(0.540569, dtype=float32), array(0.540569, dtype=float32), array(0.540569, dtype=float32)]
# Batch 25 d_loss: 0.5365200638771057
# Batch 25 g_loss: [array(0.53652006, dtype=float32), array(0.53652006, dtype=float32), array(0.53652006, dtype=float32)]
# Batch 26 d_loss: 0.5329936742782593
# Batch 26 g_loss: [array(0.5329937, dtype=float32), array(0.5329937, dtype=float32), array(0.5329937, dtype=float32)]
# Batch 27 d_loss: 0.5295987725257874
# Batch 27 g_loss: [array(0.5295988, dtype=float32), array(0.5295988, dtype=float32), array(0.5295988, dtype=float32)]
# Batch 28 d_loss: 0.526736319065094
# Batch 28 g_loss: [array(0.5267363, dtype=float32), array(0.5267363, dtype=float32), array(0.5267363, dtype=float32)]
# Batch 29 d_loss: 0.5239256620407104
# Batch 29 g_loss: [array(0.52392566, dtype=float32), array(0.52392566, dtype=float32), array(0.52392566, dtype=float32)]
# Batch 30 d_loss: 0.5211406946182251
# Batch 30 g_loss: [array(0.5211407, dtype=float32), array(0.5211407, dtype=float32), array(0.5211407, dtype=float32)]
# Batch 31 d_loss: 0.5187312960624695
# Batch 31 g_loss: [array(0.5187313, dtype=float32), array(0.5187313, dtype=float32), array(0.5187313, dtype=float32)]
# Batch 32 d_loss: 0.5163899660110474
# Batch 32 g_loss: [array(0.51638997, dtype=float32), array(0.51638997, dtype=float32), array(0.51638997, dtype=float32)]
# Batch 33 d_loss: 0.5142676830291748
# Batch 33 g_loss: [array(0.5142677, dtype=float32), array(0.5142677, dtype=float32), array(0.5142677, dtype=float32)]
# Batch 34 d_loss: 0.5122866630554199
# Batch 34 g_loss: [array(0.51228666, dtype=float32), array(0.51228666, dtype=float32), array(0.51228666, dtype=float32)]
# Batch 35 d_loss: 0.5106147527694702
# Batch 35 g_loss: [array(0.51061475, dtype=float32), array(0.51061475, dtype=float32), array(0.51061475, dtype=float32)]
# Batch 36 d_loss: 0.509299635887146
# Batch 36 g_loss: [array(0.50929964, dtype=float32), array(0.50929964, dtype=float32), array(0.50929964, dtype=float32)]
# Batch 37 d_loss: 0.5080905556678772
# Batch 37 g_loss: [array(0.50809056, dtype=float32), array(0.50809056, dtype=float32), array(0.50809056, dtype=float32)]
# Batch 38 d_loss: 0.5068194270133972
# Batch 38 g_loss: [array(0.5068194, dtype=float32), array(0.5068194, dtype=float32), array(0.5068194, dtype=float32)]
# Batch 39 d_loss: 0.5056156516075134
# Batch 39 g_loss: [array(0.50561565, dtype=float32), array(0.50561565, dtype=float32), array(0.50561565, dtype=float32)]
# Batch 40 d_loss: 0.5045238137245178
# Batch 40 g_loss: [array(0.5045238, dtype=float32), array(0.5045238, dtype=float32), array(0.5045238, dtype=float32)]
# Batch 41 d_loss: 0.5036618113517761
# Batch 41 g_loss: [array(0.5036618, dtype=float32), array(0.5036618, dtype=float32), array(0.5036618, dtype=float32)]
# Batch 42 d_loss: 0.5028076171875
# Batch 42 g_loss: [array(0.5028076, dtype=float32), array(0.5028076, dtype=float32), array(0.5028076, dtype=float32)]
# Batch 43 d_loss: 0.5019869208335876
# Batch 43 g_loss: [array(0.5019869, dtype=float32), array(0.5019869, dtype=float32), array(0.5019869, dtype=float32)]
# Batch 44 d_loss: 0.5012714266777039
# Batch 44 g_loss: [array(0.5012714, dtype=float32), array(0.5012714, dtype=float32), array(0.5012714, dtype=float32)]
# Batch 45 d_loss: 0.5005592107772827
# Batch 45 g_loss: [array(0.5005592, dtype=float32), array(0.5005592, dtype=float32), array(0.5005592, dtype=float32)]
# Batch 46 d_loss: 0.5000087022781372
# Batch 46 g_loss: [array(0.5000087, dtype=float32), array(0.5000087, dtype=float32), array(0.5000087, dtype=float32)]
# Batch 47 d_loss: 0.49971523880958557
# Batch 47 g_loss: [array(0.49971524, dtype=float32), array(0.49971524, dtype=float32), array(0.49971524, dtype=float32)]
# Batch 48 d_loss: 0.4994058310985565
# Batch 48 g_loss: [array(0.49940583, dtype=float32), array(0.49940583, dtype=float32), array(0.49940583, dtype=float32)]
# Batch 49 d_loss: 0.4989265501499176
# Batch 49 g_loss: [array(0.49892655, dtype=float32), array(0.49892655, dtype=float32), array(0.49892655, dtype=float32)]
# Batch 50 d_loss: 0.498493492603302
# Batch 50 g_loss: [array(0.4984935, dtype=float32), array(0.4984935, dtype=float32), array(0.4984935, dtype=float32)]
# Batch 51 d_loss: 0.4981124699115753
# Batch 51 g_loss: [array(0.49811247, dtype=float32), array(0.49811247, dtype=float32), array(0.49811247, dtype=float32)]
# Batch 52 d_loss: 0.4975406229496002
# Batch 52 g_loss: [array(0.49754062, dtype=float32), array(0.49754062, dtype=float32), array(0.49754062, dtype=float32)]
# Batch 53 d_loss: 0.49721038341522217
# Batch 53 g_loss: [array(0.49721038, dtype=float32), array(0.49721038, dtype=float32), array(0.49721038, dtype=float32)]
# Batch 54 d_loss: 0.49695447087287903
# Batch 54 g_loss: [array(0.49695447, dtype=float32), array(0.49695447, dtype=float32), array(0.49695447, dtype=float32)]
# Batch 55 d_loss: 0.4966246485710144
# Batch 55 g_loss: [array(0.49662465, dtype=float32), array(0.49662465, dtype=float32), array(0.49662465, dtype=float32)]
# Batch 56 d_loss: 0.4962266683578491
# Batch 56 g_loss: [array(0.49622667, dtype=float32), array(0.49622667, dtype=float32), array(0.49622667, dtype=float32)]
# Batch 57 d_loss: 0.495742529630661
# Batch 57 g_loss: [array(0.49574253, dtype=float32), array(0.49574253, dtype=float32), array(0.49574253, dtype=float32)]
# Batch 58 d_loss: 0.49538129568099976
# Batch 58 g_loss: [array(0.4953813, dtype=float32), array(0.4953813, dtype=float32), array(0.4953813, dtype=float32)]
# Batch 59 d_loss: 0.49506139755249023
# Batch 59 g_loss: [array(0.4950614, dtype=float32), array(0.4950614, dtype=float32), array(0.4950614, dtype=float32)]
# Batch 60 d_loss: 0.4946058690547943
# Batch 60 g_loss: [array(0.49460587, dtype=float32), array(0.49460587, dtype=float32), array(0.49460587, dtype=float32)]
# Batch 61 d_loss: 0.4943629801273346
# Batch 61 g_loss: [array(0.49436298, dtype=float32), array(0.49436298, dtype=float32), array(0.49436298, dtype=float32)]
# Batch 62 d_loss: 0.49406668543815613
# Batch 62 g_loss: [array(0.4940667, dtype=float32), array(0.4940667, dtype=float32), array(0.4940667, dtype=float32)]
# Batch 63 d_loss: 0.4935794770717621
# Batch 63 g_loss: [array(0.49357948, dtype=float32), array(0.49357948, dtype=float32), array(0.49357948, dtype=float32)]
# Batch 64 d_loss: 0.4931321442127228
# Batch 64 g_loss: [array(0.49313214, dtype=float32), array(0.49313214, dtype=float32), array(0.49313214, dtype=float32)]
# Batch 65 d_loss: 0.4926074147224426
# Batch 65 g_loss: [array(0.4926074, dtype=float32), array(0.4926074, dtype=float32), array(0.4926074, dtype=float32)]
# Batch 66 d_loss: 0.49204692244529724
# Batch 66 g_loss: [array(0.49204692, dtype=float32), array(0.49204692, dtype=float32), array(0.49204692, dtype=float32)]
# Batch 67 d_loss: 0.4915270507335663
# Batch 67 g_loss: [array(0.49152705, dtype=float32), array(0.49152705, dtype=float32), array(0.49152705, dtype=float32)]
# Batch 68 d_loss: 0.4908815324306488
# Batch 68 g_loss: [array(0.49088153, dtype=float32), array(0.49088153, dtype=float32), array(0.49088153, dtype=float32)]
# Batch 69 d_loss: 0.4903627634048462
# Batch 69 g_loss: [array(0.49036276, dtype=float32), array(0.49036276, dtype=float32), array(0.49036276, dtype=float32)]
# Batch 70 d_loss: 0.4897918105125427
# Batch 70 g_loss: [array(0.4897918, dtype=float32), array(0.4897918, dtype=float32), array(0.4897918, dtype=float32)]
# Batch 71 d_loss: 0.48921188712120056
# Batch 71 g_loss: [array(0.4892119, dtype=float32), array(0.4892119, dtype=float32), array(0.4892119, dtype=float32)]
# Batch 72 d_loss: 0.4885393977165222
# Batch 72 g_loss: [array(0.4885394, dtype=float32), array(0.4885394, dtype=float32), array(0.4885394, dtype=float32)]
# Batch 73 d_loss: 0.4879515469074249
# Batch 73 g_loss: [array(0.48795155, dtype=float32), array(0.48795155, dtype=float32), array(0.48795155, dtype=float32)]
# Batch 74 d_loss: 0.4873279929161072
# Batch 74 g_loss: [array(0.487328, dtype=float32), array(0.487328, dtype=float32), array(0.487328, dtype=float32)]
# Batch 75 d_loss: 0.48659104108810425
# Batch 75 g_loss: [array(0.48659104, dtype=float32), array(0.48659104, dtype=float32), array(0.48659104, dtype=float32)]
# Batch 76 d_loss: 0.48571890592575073
# Batch 76 g_loss: [array(0.4857189, dtype=float32), array(0.4857189, dtype=float32), array(0.4857189, dtype=float32)]
# Batch 77 d_loss: 0.4848887622356415
# Batch 77 g_loss: [array(0.48488876, dtype=float32), array(0.48488876, dtype=float32), array(0.48488876, dtype=float32)]
# Batch 78 d_loss: 0.483873188495636
# Batch 78 g_loss: [array(0.4838732, dtype=float32), array(0.4838732, dtype=float32), array(0.4838732, dtype=float32)]
# Batch 79 d_loss: 0.48277392983436584
# Batch 79 g_loss: [array(0.48277393, dtype=float32), array(0.48277393, dtype=float32), array(0.48277393, dtype=float32)]
# Batch 80 d_loss: 0.48159414529800415
# Batch 80 g_loss: [array(0.48159415, dtype=float32), array(0.48159415, dtype=float32), array(0.48159415, dtype=float32)]
# Batch 81 d_loss: 0.4804229736328125
# Batch 81 g_loss: [array(0.48042297, dtype=float32), array(0.48042297, dtype=float32), array(0.48042297, dtype=float32)]
# Batch 82 d_loss: 0.4792085587978363
# Batch 82 g_loss: [array(0.47920856, dtype=float32), array(0.47920856, dtype=float32), array(0.47920856, dtype=float32)]
# Batch 83 d_loss: 0.4781425893306732
# Batch 83 g_loss: [array(0.4781426, dtype=float32), array(0.4781426, dtype=float32), array(0.4781426, dtype=float32)]
# Batch 84 d_loss: 0.4768093228340149
# Batch 84 g_loss: [array(0.47680932, dtype=float32), array(0.47680932, dtype=float32), array(0.47680932, dtype=float32)]
# Batch 85 d_loss: 0.4753928482532501
# Batch 85 g_loss: [array(0.47539285, dtype=float32), array(0.47539285, dtype=float32), array(0.47539285, dtype=float32)]
# Batch 86 d_loss: 0.47407153248786926
# Batch 86 g_loss: [array(0.47407153, dtype=float32), array(0.47407153, dtype=float32), array(0.47407153, dtype=float32)]
# Batch 87 d_loss: 0.4726245701313019
# Batch 87 g_loss: [array(0.47262457, dtype=float32), array(0.47262457, dtype=float32), array(0.47262457, dtype=float32)]
# Batch 88 d_loss: 0.47123226523399353
# Batch 88 g_loss: [array(0.47123227, dtype=float32), array(0.47123227, dtype=float32), array(0.47123227, dtype=float32)]
# Batch 89 d_loss: 0.4698134660720825
# Batch 89 g_loss: [array(0.46981347, dtype=float32), array(0.46981347, dtype=float32), array(0.46981347, dtype=float32)]
# Batch 90 d_loss: 0.4683767557144165
# Batch 90 g_loss: [array(0.46837676, dtype=float32), array(0.46837676, dtype=float32), array(0.46837676, dtype=float32)]
# Batch 91 d_loss: 0.46684572100639343
# Batch 91 g_loss: [array(0.46684572, dtype=float32), array(0.46684572, dtype=float32), array(0.46684572, dtype=float32)]
# Batch 92 d_loss: 0.4652361273765564
# Batch 92 g_loss: [array(0.46523613, dtype=float32), array(0.46523613, dtype=float32), array(0.46523613, dtype=float32)]
# Batch 93 d_loss: 0.4635526239871979
# Batch 93 g_loss: [array(0.46355262, dtype=float32), array(0.46355262, dtype=float32), array(0.46355262, dtype=float32)]
# Batch 94 d_loss: 0.4618707299232483
# Batch 94 g_loss: [array(0.46187073, dtype=float32), array(0.46187073, dtype=float32), array(0.46187073, dtype=float32)]
# Batch 95 d_loss: 0.46013662219047546
# Batch 95 g_loss: [array(0.46013662, dtype=float32), array(0.46013662, dtype=float32), array(0.46013662, dtype=float32)]
# Batch 96 d_loss: 0.45852166414260864
# Batch 96 g_loss: [array(0.45852166, dtype=float32), array(0.45852166, dtype=float32), array(0.45852166, dtype=float32)]
# Batch 97 d_loss: 0.4568207263946533
# Batch 97 g_loss: [array(0.45682073, dtype=float32), array(0.45682073, dtype=float32), array(0.45682073, dtype=float32)]
# Batch 98 d_loss: 0.45514345169067383
# Batch 98 g_loss: [array(0.45514345, dtype=float32), array(0.45514345, dtype=float32), array(0.45514345, dtype=float32)]
# Batch 99 d_loss: 0.4536682367324829
# Batch 99 g_loss: [array(0.45366824, dtype=float32), array(0.45366824, dtype=float32), array(0.45366824, dtype=float32)]
# Batch 100 d_loss: 0.4521607458591461
# Batch 100 g_loss: [array(0.45216075, dtype=float32), array(0.45216075, dtype=float32), array(0.45216075, dtype=float32)]
# Batch 101 d_loss: 0.45026475191116333
# Batch 101 g_loss: [array(0.45026475, dtype=float32), array(0.45026475, dtype=float32), array(0.45026475, dtype=float32)]
# Batch 102 d_loss: 0.44833633303642273
# Batch 102 g_loss: [array(0.44833633, dtype=float32), array(0.44833633, dtype=float32), array(0.44833633, dtype=float32)]
# Batch 103 d_loss: 0.44664081931114197
# Batch 103 g_loss: [array(0.44664082, dtype=float32), array(0.44664082, dtype=float32), array(0.44664082, dtype=float32)]
# Batch 104 d_loss: 0.44479840993881226
# Batch 104 g_loss: [array(0.4447984, dtype=float32), array(0.4447984, dtype=float32), array(0.4447984, dtype=float32)]
# Batch 105 d_loss: 0.44289782643318176
# Batch 105 g_loss: [array(0.44289783, dtype=float32), array(0.44289783, dtype=float32), array(0.44289783, dtype=float32)]
# Batch 106 d_loss: 0.4412862956523895
# Batch 106 g_loss: [array(0.4412863, dtype=float32), array(0.4412863, dtype=float32), array(0.4412863, dtype=float32)]
# Batch 107 d_loss: 0.43983200192451477
# Batch 107 g_loss: [array(0.439832, dtype=float32), array(0.439832, dtype=float32), array(0.439832, dtype=float32)]
# Batch 108 d_loss: 0.43823641538619995
# Batch 108 g_loss: [array(0.43823642, dtype=float32), array(0.43823642, dtype=float32), array(0.43823642, dtype=float32)]
# Batch 109 d_loss: 0.4366375207901001
# Batch 109 g_loss: [array(0.43663752, dtype=float32), array(0.43663752, dtype=float32), array(0.43663752, dtype=float32)]
# Batch 110 d_loss: 0.43487656116485596
# Batch 110 g_loss: [array(0.43487656, dtype=float32), array(0.43487656, dtype=float32), array(0.43487656, dtype=float32)]
# Batch 111 d_loss: 0.43315985798835754
# Batch 111 g_loss: [array(0.43315986, dtype=float32), array(0.43315986, dtype=float32), array(0.43315986, dtype=float32)]
# Batch 112 d_loss: 0.4314766526222229
# Batch 112 g_loss: [array(0.43147665, dtype=float32), array(0.43147665, dtype=float32), array(0.43147665, dtype=float32)]
# Batch 113 d_loss: 0.43001824617385864
# Batch 113 g_loss: [array(0.43001825, dtype=float32), array(0.43001825, dtype=float32), array(0.43001825, dtype=float32)]
# Batch 114 d_loss: 0.42858821153640747
# Batch 114 g_loss: [array(0.4285882, dtype=float32), array(0.4285882, dtype=float32), array(0.4285882, dtype=float32)]
# Batch 115 d_loss: 0.4272943139076233
# Batch 115 g_loss: [array(0.4272943, dtype=float32), array(0.4272943, dtype=float32), array(0.4272943, dtype=float32)]
# Batch 116 d_loss: 0.42571666836738586
# Batch 116 g_loss: [array(0.42571667, dtype=float32), array(0.42571667, dtype=float32), array(0.42571667, dtype=float32)]
# Batch 117 d_loss: 0.424132376909256
# Batch 117 g_loss: [array(0.42413238, dtype=float32), array(0.42413238, dtype=float32), array(0.42413238, dtype=float32)]
# Batch 118 d_loss: 0.4227132499217987
# Batch 118 g_loss: [array(0.42271325, dtype=float32), array(0.42271325, dtype=float32), array(0.42271325, dtype=float32)]
# Batch 119 d_loss: 0.4212273061275482
# Batch 119 g_loss: [array(0.4212273, dtype=float32), array(0.4212273, dtype=float32), array(0.4212273, dtype=float32)]
# Batch 120 d_loss: 0.4199078381061554
# Batch 120 g_loss: [array(0.41990784, dtype=float32), array(0.41990784, dtype=float32), array(0.41990784, dtype=float32)]
# Batch 121 d_loss: 0.4186910092830658
# Batch 121 g_loss: [array(0.418691, dtype=float32), array(0.418691, dtype=float32), array(0.418691, dtype=float32)]
# Batch 122 d_loss: 0.417297899723053
# Batch 122 g_loss: [array(0.4172979, dtype=float32), array(0.4172979, dtype=float32), array(0.4172979, dtype=float32)]
# Batch 123 d_loss: 0.41597408056259155
# Batch 123 g_loss: [array(0.41597408, dtype=float32), array(0.41597408, dtype=float32), array(0.41597408, dtype=float32)]
# Batch 124 d_loss: 0.4145864248275757
# Batch 124 g_loss: [array(0.41458642, dtype=float32), array(0.41458642, dtype=float32), array(0.41458642, dtype=float32)]
# Batch 125 d_loss: 0.41309860348701477
# Batch 125 g_loss: [array(0.4130986, dtype=float32), array(0.4130986, dtype=float32), array(0.4130986, dtype=float32)]
# Batch 126 d_loss: 0.4116958975791931
# Batch 126 g_loss: [array(0.4116959, dtype=float32), array(0.4116959, dtype=float32), array(0.4116959, dtype=float32)]
# Batch 127 d_loss: 0.4104188084602356
# Batch 127 g_loss: [array(0.4104188, dtype=float32), array(0.4104188, dtype=float32), array(0.4104188, dtype=float32)]
# Batch 128 d_loss: 0.40908536314964294
# Batch 128 g_loss: [array(0.40908536, dtype=float32), array(0.40908536, dtype=float32), array(0.40908536, dtype=float32)]
# Batch 129 d_loss: 0.40792596340179443
# Batch 129 g_loss: [array(0.40792596, dtype=float32), array(0.40792596, dtype=float32), array(0.40792596, dtype=float32)]
# Batch 130 d_loss: 0.4068623185157776
# Batch 130 g_loss: [array(0.40686232, dtype=float32), array(0.40686232, dtype=float32), array(0.40686232, dtype=float32)]
# Batch 131 d_loss: 0.40588945150375366
# Batch 131 g_loss: [array(0.40588945, dtype=float32), array(0.40588945, dtype=float32), array(0.40588945, dtype=float32)]
# Batch 132 d_loss: 0.4048386514186859
# Batch 132 g_loss: [array(0.40483865, dtype=float32), array(0.40483865, dtype=float32), array(0.40483865, dtype=float32)]
# Batch 133 d_loss: 0.40392446517944336
# Batch 133 g_loss: [array(0.40392447, dtype=float32), array(0.40392447, dtype=float32), array(0.40392447, dtype=float32)]
# Batch 134 d_loss: 0.40281811356544495
# Batch 134 g_loss: [array(0.4028181, dtype=float32), array(0.4028181, dtype=float32), array(0.4028181, dtype=float32)]
# Batch 135 d_loss: 0.40178409218788147
# Batch 135 g_loss: [array(0.4017841, dtype=float32), array(0.4017841, dtype=float32), array(0.4017841, dtype=float32)]
# Batch 136 d_loss: 0.40092894434928894
# Batch 136 g_loss: [array(0.40092894, dtype=float32), array(0.40092894, dtype=float32), array(0.40092894, dtype=float32)]
# Batch 137 d_loss: 0.4004819989204407
# Batch 137 g_loss: [array(0.400482, dtype=float32), array(0.400482, dtype=float32), array(0.400482, dtype=float32)]
# Batch 138 d_loss: 0.3996952474117279
# Batch 138 g_loss: [array(0.39969525, dtype=float32), array(0.39969525, dtype=float32), array(0.39969525, dtype=float32)]
# Batch 139 d_loss: 0.39895036816596985
# Batch 139 g_loss: [array(0.39895037, dtype=float32), array(0.39895037, dtype=float32), array(0.39895037, dtype=float32)]
# Batch 140 d_loss: 0.3979932367801666
# Batch 140 g_loss: [array(0.39799324, dtype=float32), array(0.39799324, dtype=float32), array(0.39799324, dtype=float32)]
# Batch 141 d_loss: 0.3970980644226074
# Batch 141 g_loss: [array(0.39709806, dtype=float32), array(0.39709806, dtype=float32), array(0.39709806, dtype=float32)]
# Batch 142 d_loss: 0.39622801542282104
# Batch 142 g_loss: [array(0.39622802, dtype=float32), array(0.39622802, dtype=float32), array(0.39622802, dtype=float32)]
# Batch 143 d_loss: 0.39549490809440613
# Batch 143 g_loss: [array(0.3954949, dtype=float32), array(0.3954949, dtype=float32), array(0.3954949, dtype=float32)]
# Batch 144 d_loss: 0.3948461711406708
# Batch 144 g_loss: [array(0.39484617, dtype=float32), array(0.39484617, dtype=float32), array(0.39484617, dtype=float32)]
# Batch 145 d_loss: 0.3942849040031433
# Batch 145 g_loss: [array(0.3942849, dtype=float32), array(0.3942849, dtype=float32), array(0.3942849, dtype=float32)]
# Batch 146 d_loss: 0.39377808570861816
# Batch 146 g_loss: [array(0.3937781, dtype=float32), array(0.3937781, dtype=float32), array(0.3937781, dtype=float32)]
# Batch 147 d_loss: 0.3933182954788208
# Batch 147 g_loss: [array(0.3933183, dtype=float32), array(0.3933183, dtype=float32), array(0.3933183, dtype=float32)]
# Batch 148 d_loss: 0.3928140699863434
# Batch 148 g_loss: [array(0.39281407, dtype=float32), array(0.39281407, dtype=float32), array(0.39281407, dtype=float32)]
# Batch 149 d_loss: 0.39234742522239685
# Batch 149 g_loss: [array(0.39234743, dtype=float32), array(0.39234743, dtype=float32), array(0.39234743, dtype=float32)]
# Batch 150 d_loss: 0.3916364312171936
# Batch 150 g_loss: [array(0.39163643, dtype=float32), array(0.39163643, dtype=float32), array(0.39163643, dtype=float32)]
# Batch 151 d_loss: 0.3908628523349762
# Batch 151 g_loss: [array(0.39086285, dtype=float32), array(0.39086285, dtype=float32), array(0.39086285, dtype=float32)]
# Batch 152 d_loss: 0.3902577757835388
# Batch 152 g_loss: [array(0.39025778, dtype=float32), array(0.39025778, dtype=float32), array(0.39025778, dtype=float32)]
# Batch 153 d_loss: 0.3896107077598572
# Batch 153 g_loss: [array(0.3896107, dtype=float32), array(0.3896107, dtype=float32), array(0.3896107, dtype=float32)]
# Batch 154 d_loss: 0.388959676027298
# Batch 154 g_loss: [array(0.38895968, dtype=float32), array(0.38895968, dtype=float32), array(0.38895968, dtype=float32)]
# Batch 155 d_loss: 0.38848793506622314
# Batch 155 g_loss: [array(0.38848794, dtype=float32), array(0.38848794, dtype=float32), array(0.38848794, dtype=float32)]
# Batch 156 d_loss: 0.38796696066856384
# Batch 156 g_loss: [array(0.38796696, dtype=float32), array(0.38796696, dtype=float32), array(0.38796696, dtype=float32)]
# Batch 157 d_loss: 0.38734403252601624
# Batch 157 g_loss: [array(0.38734403, dtype=float32), array(0.38734403, dtype=float32), array(0.38734403, dtype=float32)]
# Batch 158 d_loss: 0.38682129979133606
# Batch 158 g_loss: [array(0.3868213, dtype=float32), array(0.3868213, dtype=float32), array(0.3868213, dtype=float32)]
# Batch 159 d_loss: 0.38606172800064087
# Batch 159 g_loss: [array(0.38606173, dtype=float32), array(0.38606173, dtype=float32), array(0.38606173, dtype=float32)]
# Batch 160 d_loss: 0.385339617729187
# Batch 160 g_loss: [array(0.38533962, dtype=float32), array(0.38533962, dtype=float32), array(0.38533962, dtype=float32)]
# Batch 161 d_loss: 0.38450855016708374
# Batch 161 g_loss: [array(0.38450855, dtype=float32), array(0.38450855, dtype=float32), array(0.38450855, dtype=float32)]
# Batch 162 d_loss: 0.3837742507457733
# Batch 162 g_loss: [array(0.38377425, dtype=float32), array(0.38377425, dtype=float32), array(0.38377425, dtype=float32)]
# Batch 163 d_loss: 0.383099228143692
# Batch 163 g_loss: [array(0.38309923, dtype=float32), array(0.38309923, dtype=float32), array(0.38309923, dtype=float32)]
# Batch 164 d_loss: 0.3825266659259796
# Batch 164 g_loss: [array(0.38252667, dtype=float32), array(0.38252667, dtype=float32), array(0.38252667, dtype=float32)]
# Batch 165 d_loss: 0.38187476992607117
# Batch 165 g_loss: [array(0.38187477, dtype=float32), array(0.38187477, dtype=float32), array(0.38187477, dtype=float32)]
# Batch 166 d_loss: 0.381257027387619
# Batch 166 g_loss: [array(0.38125703, dtype=float32), array(0.38125703, dtype=float32), array(0.38125703, dtype=float32)]
# Batch 167 d_loss: 0.38044238090515137
# Batch 167 g_loss: [array(0.38044238, dtype=float32), array(0.38044238, dtype=float32), array(0.38044238, dtype=float32)]
# Batch 168 d_loss: 0.3797188103199005
# Batch 168 g_loss: [array(0.3797188, dtype=float32), array(0.3797188, dtype=float32), array(0.3797188, dtype=float32)]
# Batch 169 d_loss: 0.3789438009262085
# Batch 169 g_loss: [array(0.3789438, dtype=float32), array(0.3789438, dtype=float32), array(0.3789438, dtype=float32)]
# Batch 170 d_loss: 0.3780249059200287
# Batch 170 g_loss: [array(0.3780249, dtype=float32), array(0.3780249, dtype=float32), array(0.3780249, dtype=float32)]
# Batch 171 d_loss: 0.377057284116745
# Batch 171 g_loss: [array(0.37705728, dtype=float32), array(0.37705728, dtype=float32), array(0.37705728, dtype=float32)]
# Batch 172 d_loss: 0.3764515817165375
# Batch 172 g_loss: [array(0.37645158, dtype=float32), array(0.37645158, dtype=float32), array(0.37645158, dtype=float32)]
# Batch 173 d_loss: 0.3756989538669586
# Batch 173 g_loss: [array(0.37569895, dtype=float32), array(0.37569895, dtype=float32), array(0.37569895, dtype=float32)]
# Batch 174 d_loss: 0.3747233748435974
# Batch 174 g_loss: [array(0.37472337, dtype=float32), array(0.37472337, dtype=float32), array(0.37472337, dtype=float32)]
# Batch 175 d_loss: 0.3737228512763977
# Batch 175 g_loss: [array(0.37372285, dtype=float32), array(0.37372285, dtype=float32), array(0.37372285, dtype=float32)]
# Batch 176 d_loss: 0.37266069650650024
# Batch 176 g_loss: [array(0.3726607, dtype=float32), array(0.3726607, dtype=float32), array(0.3726607, dtype=float32)]
# Batch 177 d_loss: 0.37155452370643616
# Batch 177 g_loss: [array(0.37155452, dtype=float32), array(0.37155452, dtype=float32), array(0.37155452, dtype=float32)]
# Batch 178 d_loss: 0.3704585134983063
# Batch 178 g_loss: [array(0.3704585, dtype=float32), array(0.3704585, dtype=float32), array(0.3704585, dtype=float32)]
# Batch 179 d_loss: 0.3694097399711609
# Batch 179 g_loss: [array(0.36940974, dtype=float32), array(0.36940974, dtype=float32), array(0.36940974, dtype=float32)]
# Batch 180 d_loss: 0.3683900833129883
# Batch 180 g_loss: [array(0.36839008, dtype=float32), array(0.36839008, dtype=float32), array(0.36839008, dtype=float32)]
# Batch 181 d_loss: 0.3673163950443268
# Batch 181 g_loss: [array(0.3673164, dtype=float32), array(0.3673164, dtype=float32), array(0.3673164, dtype=float32)]
# Batch 182 d_loss: 0.36627334356307983
# Batch 182 g_loss: [array(0.36627334, dtype=float32), array(0.36627334, dtype=float32), array(0.36627334, dtype=float32)]
# Batch 183 d_loss: 0.3652447462081909
# Batch 183 g_loss: [array(0.36524475, dtype=float32), array(0.36524475, dtype=float32), array(0.36524475, dtype=float32)]
# Batch 184 d_loss: 0.36426660418510437
# Batch 184 g_loss: [array(0.3642666, dtype=float32), array(0.3642666, dtype=float32), array(0.3642666, dtype=float32)]
# Batch 185 d_loss: 0.3633246123790741
# Batch 185 g_loss: [array(0.3633246, dtype=float32), array(0.3633246, dtype=float32), array(0.3633246, dtype=float32)]
# Batch 186 d_loss: 0.3623940050601959
# Batch 186 g_loss: [array(0.362394, dtype=float32), array(0.362394, dtype=float32), array(0.362394, dtype=float32)]
# Batch 187 d_loss: 0.36133942008018494
# Batch 187 g_loss: [array(0.36133942, dtype=float32), array(0.36133942, dtype=float32), array(0.36133942, dtype=float32)]
# Batch 188 d_loss: 0.3603208363056183
# Batch 188 g_loss: [array(0.36032084, dtype=float32), array(0.36032084, dtype=float32), array(0.36032084, dtype=float32)]
# Batch 189 d_loss: 0.3593902885913849
# Batch 189 g_loss: [array(0.3593903, dtype=float32), array(0.3593903, dtype=float32), array(0.3593903, dtype=float32)]
# Batch 190 d_loss: 0.35852929949760437
# Batch 190 g_loss: [array(0.3585293, dtype=float32), array(0.3585293, dtype=float32), array(0.3585293, dtype=float32)]
# Batch 191 d_loss: 0.35772600769996643
# Batch 191 g_loss: [array(0.357726, dtype=float32), array(0.357726, dtype=float32), array(0.357726, dtype=float32)]
# Batch 192 d_loss: 0.35686156153678894
# Batch 192 g_loss: [array(0.35686156, dtype=float32), array(0.35686156, dtype=float32), array(0.35686156, dtype=float32)]
# Batch 193 d_loss: 0.35592690110206604
# Batch 193 g_loss: [array(0.3559269, dtype=float32), array(0.3559269, dtype=float32), array(0.3559269, dtype=float32)]
# Batch 194 d_loss: 0.35518312454223633
# Batch 194 g_loss: [array(0.35518312, dtype=float32), array(0.35518312, dtype=float32), array(0.35518312, dtype=float32)]
# Batch 195 d_loss: 0.35448580980300903
# Batch 195 g_loss: [array(0.3544858, dtype=float32), array(0.3544858, dtype=float32), array(0.3544858, dtype=float32)]
# Batch 196 d_loss: 0.3538166582584381
# Batch 196 g_loss: [array(0.35381666, dtype=float32), array(0.35381666, dtype=float32), array(0.35381666, dtype=float32)]
# Batch 197 d_loss: 0.3531287610530853
# Batch 197 g_loss: [array(0.35312876, dtype=float32), array(0.35312876, dtype=float32), array(0.35312876, dtype=float32)]
# Batch 198 d_loss: 0.35237982869148254
# Batch 198 g_loss: [array(0.35237983, dtype=float32), array(0.35237983, dtype=float32), array(0.35237983, dtype=float32)]
# Batch 199 d_loss: 0.35173043608665466
# Batch 199 g_loss: [array(0.35173044, dtype=float32), array(0.35173044, dtype=float32), array(0.35173044, dtype=float32)]
# Batch 200 d_loss: 0.35119393467903137
# Batch 200 g_loss: [array(0.35119393, dtype=float32), array(0.35119393, dtype=float32), array(0.35119393, dtype=float32)]
# Batch 201 d_loss: 0.35064369440078735
# Batch 201 g_loss: [array(0.3506437, dtype=float32), array(0.3506437, dtype=float32), array(0.3506437, dtype=float32)]
# Batch 202 d_loss: 0.35023197531700134
# Batch 202 g_loss: [array(0.35023198, dtype=float32), array(0.35023198, dtype=float32), array(0.35023198, dtype=float32)]
# Batch 203 d_loss: 0.34973472356796265
# Batch 203 g_loss: [array(0.34973472, dtype=float32), array(0.34973472, dtype=float32), array(0.34973472, dtype=float32)]
# Batch 204 d_loss: 0.3492349088191986
# Batch 204 g_loss: [array(0.3492349, dtype=float32), array(0.3492349, dtype=float32), array(0.3492349, dtype=float32)]
# Batch 205 d_loss: 0.3488300144672394
# Batch 205 g_loss: [array(0.34883, dtype=float32), array(0.34883, dtype=float32), array(0.34883, dtype=float32)]
# Batch 206 d_loss: 0.34856218099594116
# Batch 206 g_loss: [array(0.34856218, dtype=float32), array(0.34856218, dtype=float32), array(0.34856218, dtype=float32)]
# Batch 207 d_loss: 0.3484877347946167
# Batch 207 g_loss: [array(0.34848773, dtype=float32), array(0.34848773, dtype=float32), array(0.34848773, dtype=float32)]
# Batch 208 d_loss: 0.3480641841888428
# Batch 208 g_loss: [array(0.34806418, dtype=float32), array(0.34806418, dtype=float32), array(0.34806418, dtype=float32)]
# Batch 209 d_loss: 0.34761932492256165
# Batch 209 g_loss: [array(0.34761932, dtype=float32), array(0.34761932, dtype=float32), array(0.34761932, dtype=float32)]
# Batch 210 d_loss: 0.3472804129123688
# Batch 210 g_loss: [array(0.3472804, dtype=float32), array(0.3472804, dtype=float32), array(0.3472804, dtype=float32)]
# Batch 211 d_loss: 0.34698039293289185
# Batch 211 g_loss: [array(0.3469804, dtype=float32), array(0.3469804, dtype=float32), array(0.3469804, dtype=float32)]
# Batch 212 d_loss: 0.3468148708343506
# Batch 212 g_loss: [array(0.34681487, dtype=float32), array(0.34681487, dtype=float32), array(0.34681487, dtype=float32)]
# Batch 213 d_loss: 0.34685173630714417
# Batch 213 g_loss: [array(0.34685174, dtype=float32), array(0.34685174, dtype=float32), array(0.34685174, dtype=float32)]
# Batch 214 d_loss: 0.34702983498573303
# Batch 214 g_loss: [array(0.34702983, dtype=float32), array(0.34702983, dtype=float32), array(0.34702983, dtype=float32)]
# Batch 215 d_loss: 0.3467642366886139
# Batch 215 g_loss: [array(0.34676424, dtype=float32), array(0.34676424, dtype=float32), array(0.34676424, dtype=float32)]
# Batch 216 d_loss: 0.34672898054122925
# Batch 216 g_loss: [array(0.34672898, dtype=float32), array(0.34672898, dtype=float32), array(0.34672898, dtype=float32)]
# Batch 217 d_loss: 0.34670326113700867
# Batch 217 g_loss: [array(0.34670326, dtype=float32), array(0.34670326, dtype=float32), array(0.34670326, dtype=float32)]
# Batch 218 d_loss: 0.34634384512901306
# Batch 218 g_loss: [array(0.34634385, dtype=float32), array(0.34634385, dtype=float32), array(0.34634385, dtype=float32)]
# Batch 219 d_loss: 0.34595683217048645
# Batch 219 g_loss: [array(0.34595683, dtype=float32), array(0.34595683, dtype=float32), array(0.34595683, dtype=float32)]
# Batch 220 d_loss: 0.3456520438194275
# Batch 220 g_loss: [array(0.34565204, dtype=float32), array(0.34565204, dtype=float32), array(0.34565204, dtype=float32)]
# Batch 221 d_loss: 0.3453174829483032
# Batch 221 g_loss: [array(0.34531748, dtype=float32), array(0.34531748, dtype=float32), array(0.34531748, dtype=float32)]
# Batch 222 d_loss: 0.3449714183807373
# Batch 222 g_loss: [array(0.34497142, dtype=float32), array(0.34497142, dtype=float32), array(0.34497142, dtype=float32)]
# Batch 223 d_loss: 0.3447363078594208
# Batch 223 g_loss: [array(0.3447363, dtype=float32), array(0.3447363, dtype=float32), array(0.3447363, dtype=float32)]
# Batch 224 d_loss: 0.34438058733940125
# Batch 224 g_loss: [array(0.3443806, dtype=float32), array(0.3443806, dtype=float32), array(0.3443806, dtype=float32)]
# Batch 225 d_loss: 0.34413382411003113
# Batch 225 g_loss: [array(0.34413382, dtype=float32), array(0.34413382, dtype=float32), array(0.34413382, dtype=float32)]
# Batch 226 d_loss: 0.3439278304576874
# Batch 226 g_loss: [array(0.34392783, dtype=float32), array(0.34392783, dtype=float32), array(0.34392783, dtype=float32)]
# Batch 227 d_loss: 0.3438790440559387
# Batch 227 g_loss: [array(0.34387904, dtype=float32), array(0.34387904, dtype=float32), array(0.34387904, dtype=float32)]
# Batch 228 d_loss: 0.3437110483646393
# Batch 228 g_loss: [array(0.34371105, dtype=float32), array(0.34371105, dtype=float32), array(0.34371105, dtype=float32)]
# Batch 229 d_loss: 0.3432929515838623
# Batch 229 g_loss: [array(0.34329295, dtype=float32), array(0.34329295, dtype=float32), array(0.34329295, dtype=float32)]
# Batch 230 d_loss: 0.3429166376590729
# Batch 230 g_loss: [array(0.34291664, dtype=float32), array(0.34291664, dtype=float32), array(0.34291664, dtype=float32)]
# Batch 231 d_loss: 0.3427104353904724
# Batch 231 g_loss: [array(0.34271044, dtype=float32), array(0.34271044, dtype=float32), array(0.34271044, dtype=float32)]
# Batch 232 d_loss: 0.3424433469772339
# Batch 232 g_loss: [array(0.34244335, dtype=float32), array(0.34244335, dtype=float32), array(0.34244335, dtype=float32)]
# Batch 233 d_loss: 0.3423556387424469
# Batch 233 g_loss: [array(0.34235564, dtype=float32), array(0.34235564, dtype=float32), array(0.34235564, dtype=float32)]
# Batch 234 d_loss: 0.34228983521461487
# Batch 234 g_loss: [array(0.34228984, dtype=float32), array(0.34228984, dtype=float32), array(0.34228984, dtype=float32)]
# Batch 235 d_loss: 0.3421877920627594
# Batch 235 g_loss: [array(0.3421878, dtype=float32), array(0.3421878, dtype=float32), array(0.3421878, dtype=float32)]
# Batch 236 d_loss: 0.3419579565525055
# Batch 236 g_loss: [array(0.34195796, dtype=float32), array(0.34195796, dtype=float32), array(0.34195796, dtype=float32)]
# Batch 237 d_loss: 0.34175077080726624
# Batch 237 g_loss: [array(0.34175077, dtype=float32), array(0.34175077, dtype=float32), array(0.34175077, dtype=float32)]
# Batch 238 d_loss: 0.34146010875701904
# Batch 238 g_loss: [array(0.3414601, dtype=float32), array(0.3414601, dtype=float32), array(0.3414601, dtype=float32)]
# Batch 239 d_loss: 0.3415807783603668
# Batch 239 g_loss: [array(0.34158078, dtype=float32), array(0.34158078, dtype=float32), array(0.34158078, dtype=float32)]
# Batch 240 d_loss: 0.34150421619415283
# Batch 240 g_loss: [array(0.34150422, dtype=float32), array(0.34150422, dtype=float32), array(0.34150422, dtype=float32)]
# Batch 241 d_loss: 0.34119346737861633
# Batch 241 g_loss: [array(0.34119347, dtype=float32), array(0.34119347, dtype=float32), array(0.34119347, dtype=float32)]
# Batch 242 d_loss: 0.3410697281360626
# Batch 242 g_loss: [array(0.34106973, dtype=float32), array(0.34106973, dtype=float32), array(0.34106973, dtype=float32)]
# Batch 243 d_loss: 0.34133344888687134
# Batch 243 g_loss: [array(0.34133345, dtype=float32), array(0.34133345, dtype=float32), array(0.34133345, dtype=float32)]
# Batch 244 d_loss: 0.3412421643733978
# Batch 244 g_loss: [array(0.34124216, dtype=float32), array(0.34124216, dtype=float32), array(0.34124216, dtype=float32)]
# Batch 245 d_loss: 0.34129080176353455
# Batch 245 g_loss: [array(0.3412908, dtype=float32), array(0.3412908, dtype=float32), array(0.3412908, dtype=float32)]
# Batch 246 d_loss: 0.3413914442062378
# Batch 246 g_loss: [array(0.34139144, dtype=float32), array(0.34139144, dtype=float32), array(0.34139144, dtype=float32)]
# Batch 247 d_loss: 0.341647207736969
# Batch 247 g_loss: [array(0.3416472, dtype=float32), array(0.3416472, dtype=float32), array(0.3416472, dtype=float32)]
# Batch 248 d_loss: 0.3418183922767639
# Batch 248 g_loss: [array(0.3418184, dtype=float32), array(0.3418184, dtype=float32), array(0.3418184, dtype=float32)]
# Batch 249 d_loss: 0.34192225337028503
# Batch 249 g_loss: [array(0.34192225, dtype=float32), array(0.34192225, dtype=float32), array(0.34192225, dtype=float32)]
# Batch 250 d_loss: 0.341763436794281
# Batch 250 g_loss: [array(0.34176344, dtype=float32), array(0.34176344, dtype=float32), array(0.34176344, dtype=float32)]
# Batch 251 d_loss: 0.34194549918174744
# Batch 251 g_loss: [array(0.3419455, dtype=float32), array(0.3419455, dtype=float32), array(0.3419455, dtype=float32)]
# Batch 252 d_loss: 0.34180477261543274
# Batch 252 g_loss: [array(0.34180477, dtype=float32), array(0.34180477, dtype=float32), array(0.34180477, dtype=float32)]
# Batch 253 d_loss: 0.3417696952819824
# Batch 253 g_loss: [array(0.3417697, dtype=float32), array(0.3417697, dtype=float32), array(0.3417697, dtype=float32)]
# Batch 254 d_loss: 0.34205523133277893
# Batch 254 g_loss: [array(0.34205523, dtype=float32), array(0.34205523, dtype=float32), array(0.34205523, dtype=float32)]
# Batch 255 d_loss: 0.34250473976135254
# Batch 255 g_loss: [array(0.34250474, dtype=float32), array(0.34250474, dtype=float32), array(0.34250474, dtype=float32)]
# Batch 256 d_loss: 0.3427998721599579
# Batch 256 g_loss: [array(0.34279987, dtype=float32), array(0.34279987, dtype=float32), array(0.34279987, dtype=float32)]
# Batch 257 d_loss: 0.34289973974227905
# Batch 257 g_loss: [array(0.34289974, dtype=float32), array(0.34289974, dtype=float32), array(0.34289974, dtype=float32)]
# Batch 258 d_loss: 0.3431738018989563
# Batch 258 g_loss: [array(0.3431738, dtype=float32), array(0.3431738, dtype=float32), array(0.3431738, dtype=float32)]
# Batch 259 d_loss: 0.3434487581253052
# Batch 259 g_loss: [array(0.34344876, dtype=float32), array(0.34344876, dtype=float32), array(0.34344876, dtype=float32)]
# Batch 260 d_loss: 0.34412914514541626
# Batch 260 g_loss: [array(0.34412915, dtype=float32), array(0.34412915, dtype=float32), array(0.34412915, dtype=float32)]
# Batch 261 d_loss: 0.3449344336986542
# Batch 261 g_loss: [array(0.34493443, dtype=float32), array(0.34493443, dtype=float32), array(0.34493443, dtype=float32)]
# Batch 262 d_loss: 0.3458091616630554
# Batch 262 g_loss: [array(0.34580916, dtype=float32), array(0.34580916, dtype=float32), array(0.34580916, dtype=float32)]
# Batch 263 d_loss: 0.3462623953819275
# Batch 263 g_loss: [array(0.3462624, dtype=float32), array(0.3462624, dtype=float32), array(0.3462624, dtype=float32)]
# Batch 264 d_loss: 0.346449613571167
# Batch 264 g_loss: [array(0.3464496, dtype=float32), array(0.3464496, dtype=float32), array(0.3464496, dtype=float32)]
# Batch 265 d_loss: 0.34722110629081726
# Batch 265 g_loss: [array(0.3472211, dtype=float32), array(0.3472211, dtype=float32), array(0.3472211, dtype=float32)]
# Batch 266 d_loss: 0.34777840971946716
# Batch 266 g_loss: [array(0.3477784, dtype=float32), array(0.3477784, dtype=float32), array(0.3477784, dtype=float32)]
# Batch 267 d_loss: 0.3485398590564728
# Batch 267 g_loss: [array(0.34853986, dtype=float32), array(0.34853986, dtype=float32), array(0.34853986, dtype=float32)]
# Batch 268 d_loss: 0.34906500577926636
# Batch 268 g_loss: [array(0.349065, dtype=float32), array(0.349065, dtype=float32), array(0.349065, dtype=float32)]
# Batch 269 d_loss: 0.34975960850715637
# Batch 269 g_loss: [array(0.3497596, dtype=float32), array(0.3497596, dtype=float32), array(0.3497596, dtype=float32)]
# Batch 270 d_loss: 0.3504006862640381
# Batch 270 g_loss: [array(0.3504007, dtype=float32), array(0.3504007, dtype=float32), array(0.3504007, dtype=float32)]
# Batch 271 d_loss: 0.35118022561073303
# Batch 271 g_loss: [array(0.35118023, dtype=float32), array(0.35118023, dtype=float32), array(0.35118023, dtype=float32)]
# Batch 272 d_loss: 0.35191604495048523
# Batch 272 g_loss: [array(0.35191604, dtype=float32), array(0.35191604, dtype=float32), array(0.35191604, dtype=float32)]
# Batch 273 d_loss: 0.35237497091293335
# Batch 273 g_loss: [array(0.35237497, dtype=float32), array(0.35237497, dtype=float32), array(0.35237497, dtype=float32)]
# Batch 274 d_loss: 0.3531130850315094
# Batch 274 g_loss: [array(0.35311309, dtype=float32), array(0.35311309, dtype=float32), array(0.35311309, dtype=float32)]
# Batch 275 d_loss: 0.3541916012763977
# Batch 275 g_loss: [array(0.3541916, dtype=float32), array(0.3541916, dtype=float32), array(0.3541916, dtype=float32)]
# Batch 276 d_loss: 0.35491806268692017
# Batch 276 g_loss: [array(0.35491806, dtype=float32), array(0.35491806, dtype=float32), array(0.35491806, dtype=float32)]
# Batch 277 d_loss: 0.35570892691612244
# Batch 277 g_loss: [array(0.35570893, dtype=float32), array(0.35570893, dtype=float32), array(0.35570893, dtype=float32)]
# Batch 278 d_loss: 0.3566976487636566
# Batch 278 g_loss: [array(0.35669765, dtype=float32), array(0.35669765, dtype=float32), array(0.35669765, dtype=float32)]
# Batch 279 d_loss: 0.35760676860809326
# Batch 279 g_loss: [array(0.35760677, dtype=float32), array(0.35760677, dtype=float32), array(0.35760677, dtype=float32)]
# Batch 280 d_loss: 0.35927173495292664
# Batch 280 g_loss: [array(0.35927173, dtype=float32), array(0.35927173, dtype=float32), array(0.35927173, dtype=float32)]
# Batch 281 d_loss: 0.3608146905899048
# Batch 281 g_loss: [array(0.3608147, dtype=float32), array(0.3608147, dtype=float32), array(0.3608147, dtype=float32)]
# Batch 282 d_loss: 0.3615748882293701
# Batch 282 g_loss: [array(0.3615749, dtype=float32), array(0.3615749, dtype=float32), array(0.3615749, dtype=float32)]
# Batch 283 d_loss: 0.36231526732444763
# Batch 283 g_loss: [array(0.36231527, dtype=float32), array(0.36231527, dtype=float32), array(0.36231527, dtype=float32)]
# Batch 284 d_loss: 0.363295316696167
# Batch 284 g_loss: [array(0.36329532, dtype=float32), array(0.36329532, dtype=float32), array(0.36329532, dtype=float32)]
# Batch 285 d_loss: 0.3640468716621399
# Batch 285 g_loss: [array(0.36404687, dtype=float32), array(0.36404687, dtype=float32), array(0.36404687, dtype=float32)]
# Batch 286 d_loss: 0.36443132162094116
# Batch 286 g_loss: [array(0.36443132, dtype=float32), array(0.36443132, dtype=float32), array(0.36443132, dtype=float32)]
# Batch 287 d_loss: 0.3649348020553589
# Batch 287 g_loss: [array(0.3649348, dtype=float32), array(0.3649348, dtype=float32), array(0.3649348, dtype=float32)]
# Batch 288 d_loss: 0.3656715452671051
# Batch 288 g_loss: [array(0.36567155, dtype=float32), array(0.36567155, dtype=float32), array(0.36567155, dtype=float32)]
# Batch 289 d_loss: 0.3664136230945587
# Batch 289 g_loss: [array(0.36641362, dtype=float32), array(0.36641362, dtype=float32), array(0.36641362, dtype=float32)]
# Batch 290 d_loss: 0.36683180928230286
# Batch 290 g_loss: [array(0.3668318, dtype=float32), array(0.3668318, dtype=float32), array(0.3668318, dtype=float32)]
# Batch 291 d_loss: 0.36743664741516113
# Batch 291 g_loss: [array(0.36743665, dtype=float32), array(0.36743665, dtype=float32), array(0.36743665, dtype=float32)]
# Batch 292 d_loss: 0.36831942200660706
# Batch 292 g_loss: [array(0.36831942, dtype=float32), array(0.36831942, dtype=float32), array(0.36831942, dtype=float32)]
# Batch 293 d_loss: 0.3696874976158142
# Batch 293 g_loss: [array(0.3696875, dtype=float32), array(0.3696875, dtype=float32), array(0.3696875, dtype=float32)]
# Batch 294 d_loss: 0.37079137563705444
# Batch 294 g_loss: [array(0.37079138, dtype=float32), array(0.37079138, dtype=float32), array(0.37079138, dtype=float32)]
# Batch 295 d_loss: 0.3714532256126404
# Batch 295 g_loss: [array(0.37145323, dtype=float32), array(0.37145323, dtype=float32), array(0.37145323, dtype=float32)]
# Batch 296 d_loss: 0.37219998240470886
# Batch 296 g_loss: [array(0.37219998, dtype=float32), array(0.37219998, dtype=float32), array(0.37219998, dtype=float32)]
# Batch 297 d_loss: 0.37292546033859253
# ...
# Batch 273 d_loss: 0.4576418101787567
# Batch 273 g_loss: [array(0.4576418, dtype=float32), array(0.4576418, dtype=float32), array(0.4576418, dtype=float32)]
# Batch 274 d_loss: 0.4576234817504883
# Batch 274 g_loss: [array(0.45762348, dtype=float32), array(0.45762348, dtype=float32), array(0.45762348, dtype=float32)]
# Batch 275 d_loss: 0.45764827728271484
# Batch 275 g_loss: [array(0.45764828, dtype=float32), array(0.45764828, dtype=float32), array(0.45764828, dtype=float32)]
# Batch 276 d_loss: 0.45765429735183716
# Batch 276 g_loss: [array(0.4576543, dtype=float32), array(0.4576543, dtype=float32), array(0.4576543, dtype=float32)]
# Batch 277 d_loss: 0.45769035816192627
# Batch 277 g_loss: [array(0.45769036, dtype=float32), array(0.45769036, dtype=float32), array(0.45769036, dtype=float32)]
# Batch 278 d_loss: 0.45769914984703064
# Batch 278 g_loss: [array(0.45769915, dtype=float32), array(0.45769915, dtype=float32), array(0.45769915, dtype=float32)]
# Batch 279 d_loss: 0.4576572775840759
# Batch 279 g_loss: [array(0.45765728, dtype=float32), array(0.45765728, dtype=float32), array(0.45765728, dtype=float32)]
# Batch 280 d_loss: 0.4576706886291504
# Batch 280 g_loss: [array(0.4576707, dtype=float32), array(0.4576707, dtype=float32), array(0.4576707, dtype=float32)]
# Batch 281 d_loss: 0.4576954245567322
# Batch 281 g_loss: [array(0.45769542, dtype=float32), array(0.45769542, dtype=float32), array(0.45769542, dtype=float32)]
# Batch 282 d_loss: 0.4577524960041046
# Batch 282 g_loss: [array(0.4577525, dtype=float32), array(0.4577525, dtype=float32), array(0.4577525, dtype=float32)]
# Batch 283 d_loss: 0.457813024520874
# Batch 283 g_loss: [array(0.45781302, dtype=float32), array(0.45781302, dtype=float32), array(0.45781302, dtype=float32)]
# Batch 284 d_loss: 0.45779985189437866
# Batch 284 g_loss: [array(0.45779985, dtype=float32), array(0.45779985, dtype=float32), array(0.45779985, dtype=float32)]
# Batch 285 d_loss: 0.45778438448905945
# Batch 285 g_loss: [array(0.45778438, dtype=float32), array(0.45778438, dtype=float32), array(0.45778438, dtype=float32)]
# Batch 286 d_loss: 0.457766592502594
# Batch 286 g_loss: [array(0.4577666, dtype=float32), array(0.4577666, dtype=float32), array(0.4577666, dtype=float32)]
# Batch 287 d_loss: 0.4577404260635376
# Batch 287 g_loss: [array(0.45774043, dtype=float32), array(0.45774043, dtype=float32), array(0.45774043, dtype=float32)]
# Batch 288 d_loss: 0.45770135521888733
# Batch 288 g_loss: [array(0.45770136, dtype=float32), array(0.45770136, dtype=float32), array(0.45770136, dtype=float32)]
# Batch 289 d_loss: 0.45770367980003357
# Batch 289 g_loss: [array(0.45770368, dtype=float32), array(0.45770368, dtype=float32), array(0.45770368, dtype=float32)]
# Batch 290 d_loss: 0.4577454924583435
# Batch 290 g_loss: [array(0.4577455, dtype=float32), array(0.4577455, dtype=float32), array(0.4577455, dtype=float32)]
# Batch 291 d_loss: 0.4577780067920685
# Batch 291 g_loss: [array(0.457778, dtype=float32), array(0.457778, dtype=float32), array(0.457778, dtype=float32)]
# Batch 292 d_loss: 0.457861065864563
# Batch 292 g_loss: [array(0.45786107, dtype=float32), array(0.45786107, dtype=float32), array(0.45786107, dtype=float32)]
# Batch 293 d_loss: 0.45789602398872375
# Batch 293 g_loss: [array(0.45789602, dtype=float32), array(0.45789602, dtype=float32), array(0.45789602, dtype=float32)]
# Batch 294 d_loss: 0.45791181921958923
# Batch 294 g_loss: [array(0.45791182, dtype=float32), array(0.45791182, dtype=float32), array(0.45791182, dtype=float32)]
# Batch 295 d_loss: 0.4579595923423767
# Batch 295 g_loss: [array(0.4579596, dtype=float32), array(0.4579596, dtype=float32), array(0.4579596, dtype=float32)]
# Batch 296 d_loss: 0.45797136425971985
# Batch 296 g_loss: [array(0.45797136, dtype=float32), array(0.45797136, dtype=float32), array(0.45797136, dtype=float32)]
# Batch 297 d_loss: 0.45795196294784546
# Batch 297 g_loss: [array(0.45795196, dtype=float32), array(0.45795196, dtype=float32), array(0.45795196, dtype=float32)]
# Batch 298 d_loss: 0.45795172452926636
# Batch 298 g_loss: [array(0.45795172, dtype=float32), array(0.45795172, dtype=float32), array(0.45795172, dtype=float32)]
# Batch 299 d_loss: 0.45798924565315247
# Batch 299 g_loss: [array(0.45798925, dtype=float32), array(0.45798925, dtype=float32), array(0.45798925, dtype=float32)]
# Batch 300 d_loss: 0.45800402760505676
# Batch 300 g_loss: [array(0.45800403, dtype=float32), array(0.45800403, dtype=float32), array(0.45800403, dtype=float32)]
# Batch 301 d_loss: 0.4580424427986145
# Batch 301 g_loss: [array(0.45804244, dtype=float32), array(0.45804244, dtype=float32), array(0.45804244, dtype=float32)]
# Batch 302 d_loss: 0.4580442011356354
# Batch 302 g_loss: [array(0.4580442, dtype=float32), array(0.4580442, dtype=float32), array(0.4580442, dtype=float32)]
# Batch 303 d_loss: 0.4580082893371582
# Batch 303 g_loss: [array(0.4580083, dtype=float32), array(0.4580083, dtype=float32), array(0.4580083, dtype=float32)]
# Batch 304 d_loss: 0.4579709768295288
# Batch 304 g_loss: [array(0.45797098, dtype=float32), array(0.45797098, dtype=float32), array(0.45797098, dtype=float32)]
# Batch 305 d_loss: 0.4579659104347229
# Batch 305 g_loss: [array(0.4579659, dtype=float32), array(0.4579659, dtype=float32), array(0.4579659, dtype=float32)]
# Batch 306 d_loss: 0.4579366445541382
# Batch 306 g_loss: [array(0.45793664, dtype=float32), array(0.45793664, dtype=float32), array(0.45793664, dtype=float32)]
# Batch 307 d_loss: 0.4580114185810089
# Batch 307 g_loss: [array(0.45801142, dtype=float32), array(0.45801142, dtype=float32), array(0.45801142, dtype=float32)]
# Batch 308 d_loss: 0.4580860435962677
# Batch 308 g_loss: [array(0.45808604, dtype=float32), array(0.45808604, dtype=float32), array(0.45808604, dtype=float32)]
# Batch 309 d_loss: 0.45811599493026733
# Batch 309 g_loss: [array(0.458116, dtype=float32), array(0.458116, dtype=float32), array(0.458116, dtype=float32)]
# Batch 310 d_loss: 0.4581291377544403
# Batch 310 g_loss: [array(0.45812914, dtype=float32), array(0.45812914, dtype=float32), array(0.45812914, dtype=float32)]
# Batch 311 d_loss: 0.45816004276275635
# Batch 311 g_loss: [array(0.45816004, dtype=float32), array(0.45816004, dtype=float32), array(0.45816004, dtype=float32)]
# Batch 312 d_loss: 0.4581277668476105
# Batch 312 g_loss: [array(0.45812777, dtype=float32), array(0.45812777, dtype=float32), array(0.45812777, dtype=float32)]
# Batch 313 d_loss: 0.45812901854515076
# Batch 313 g_loss: [array(0.45812902, dtype=float32), array(0.45812902, dtype=float32), array(0.45812902, dtype=float32)]
# Batch 314 d_loss: 0.4580901563167572
# Batch 314 g_loss: [array(0.45809016, dtype=float32), array(0.45809016, dtype=float32), array(0.45809016, dtype=float32)]
# Batch 315 d_loss: 0.45805349946022034
# Batch 315 g_loss: [array(0.4580535, dtype=float32), array(0.4580535, dtype=float32), array(0.4580535, dtype=float32)]
# Batch 316 d_loss: 0.45814377069473267
# Batch 316 g_loss: [array(0.45814377, dtype=float32), array(0.45814377, dtype=float32), array(0.45814377, dtype=float32)]
# Batch 317 d_loss: 0.45816120505332947
# Batch 317 g_loss: [array(0.4581612, dtype=float32), array(0.4581612, dtype=float32), array(0.4581612, dtype=float32)]
# Batch 318 d_loss: 0.45817893743515015
# Batch 318 g_loss: [array(0.45817894, dtype=float32), array(0.45817894, dtype=float32), array(0.45817894, dtype=float32)]
# Batch 319 d_loss: 0.4582151174545288
# Batch 319 g_loss: [array(0.45821512, dtype=float32), array(0.45821512, dtype=float32), array(0.45821512, dtype=float32)]
# Batch 320 d_loss: 0.4582294821739197
# Batch 320 g_loss: [array(0.45822948, dtype=float32), array(0.45822948, dtype=float32), array(0.45822948, dtype=float32)]
# Batch 321 d_loss: 0.4581988453865051
# Batch 321 g_loss: [array(0.45819885, dtype=float32), array(0.45819885, dtype=float32), array(0.45819885, dtype=float32)]
# Batch 322 d_loss: 0.4582675099372864
# Batch 322 g_loss: [array(0.4582675, dtype=float32), array(0.4582675, dtype=float32), array(0.4582675, dtype=float32)]
# Batch 323 d_loss: 0.45834454894065857
# Batch 323 g_loss: [array(0.45834455, dtype=float32), array(0.45834455, dtype=float32), array(0.45834455, dtype=float32)]
# Batch 324 d_loss: 0.4584212303161621
# Batch 324 g_loss: [array(0.45842123, dtype=float32), array(0.45842123, dtype=float32), array(0.45842123, dtype=float32)]
# Batch 325 d_loss: 0.4584272503852844
# Batch 325 g_loss: [array(0.45842725, dtype=float32), array(0.45842725, dtype=float32), array(0.45842725, dtype=float32)]
# Batch 326 d_loss: 0.45843467116355896
# Batch 326 g_loss: [array(0.45843467, dtype=float32), array(0.45843467, dtype=float32), array(0.45843467, dtype=float32)]
# Batch 327 d_loss: 0.45847415924072266
# Batch 327 g_loss: [array(0.45847416, dtype=float32), array(0.45847416, dtype=float32), array(0.45847416, dtype=float32)]
# Batch 328 d_loss: 0.45847415924072266
# Batch 328 g_loss: [array(0.45847416, dtype=float32), array(0.45847416, dtype=float32), array(0.45847416, dtype=float32)]
# Batch 329 d_loss: 0.4585009515285492
# Batch 329 g_loss: [array(0.45850095, dtype=float32), array(0.45850095, dtype=float32), array(0.45850095, dtype=float32)]
# Batch 330 d_loss: 0.45859771966934204
# Batch 330 g_loss: [array(0.45859772, dtype=float32), array(0.45859772, dtype=float32), array(0.45859772, dtype=float32)]
# Batch 331 d_loss: 0.458668977022171
# Batch 331 g_loss: [array(0.45866898, dtype=float32), array(0.45866898, dtype=float32), array(0.45866898, dtype=float32)]
# Batch 332 d_loss: 0.45868709683418274
# Batch 332 g_loss: [array(0.4586871, dtype=float32), array(0.4586871, dtype=float32), array(0.4586871, dtype=float32)]
# Batch 333 d_loss: 0.4587271213531494
# Batch 333 g_loss: [array(0.45872712, dtype=float32), array(0.45872712, dtype=float32), array(0.45872712, dtype=float32)]
# Batch 334 d_loss: 0.45869284868240356
# Batch 334 g_loss: [array(0.45869285, dtype=float32), array(0.45869285, dtype=float32), array(0.45869285, dtype=float32)]
# Batch 335 d_loss: 0.45862773060798645
# Batch 335 g_loss: [array(0.45862773, dtype=float32), array(0.45862773, dtype=float32), array(0.45862773, dtype=float32)]
# Batch 336 d_loss: 0.45853954553604126
# Batch 336 g_loss: [array(0.45853955, dtype=float32), array(0.45853955, dtype=float32), array(0.45853955, dtype=float32)]
# Batch 337 d_loss: 0.4584774971008301
# Batch 337 g_loss: [array(0.4584775, dtype=float32), array(0.4584775, dtype=float32), array(0.4584775, dtype=float32)]
# Batch 338 d_loss: 0.4584168791770935
# Batch 338 g_loss: [array(0.45841688, dtype=float32), array(0.45841688, dtype=float32), array(0.45841688, dtype=float32)]
# Batch 339 d_loss: 0.4583728015422821
# Batch 339 g_loss: [array(0.4583728, dtype=float32), array(0.4583728, dtype=float32), array(0.4583728, dtype=float32)]
# Batch 340 d_loss: 0.45834851264953613
# Batch 340 g_loss: [array(0.4583485, dtype=float32), array(0.4583485, dtype=float32), array(0.4583485, dtype=float32)]
# Batch 341 d_loss: 0.4582851827144623
# Batch 341 g_loss: [array(0.45828518, dtype=float32), array(0.45828518, dtype=float32), array(0.45828518, dtype=float32)]
# Batch 342 d_loss: 0.45823022723197937
# Batch 342 g_loss: [array(0.45823023, dtype=float32), array(0.45823023, dtype=float32), array(0.45823023, dtype=float32)]
# Batch 343 d_loss: 0.45817649364471436
# Batch 343 g_loss: [array(0.4581765, dtype=float32), array(0.4581765, dtype=float32), array(0.4581765, dtype=float32)]
# Batch 344 d_loss: 0.45820102095603943
# Batch 344 g_loss: [array(0.45820102, dtype=float32), array(0.45820102, dtype=float32), array(0.45820102, dtype=float32)]
# Batch 345 d_loss: 0.4582061469554901
# Batch 345 g_loss: [array(0.45820615, dtype=float32), array(0.45820615, dtype=float32), array(0.45820615, dtype=float32)]
# Batch 346 d_loss: 0.4581841826438904
# Batch 346 g_loss: [array(0.45818418, dtype=float32), array(0.45818418, dtype=float32), array(0.45818418, dtype=float32)]
# Batch 347 d_loss: 0.45817291736602783
# Batch 347 g_loss: [array(0.45817292, dtype=float32), array(0.45817292, dtype=float32), array(0.45817292, dtype=float32)]
# Batch 348 d_loss: 0.45812490582466125
# Batch 348 g_loss: [array(0.4581249, dtype=float32), array(0.4581249, dtype=float32), array(0.4581249, dtype=float32)]
# Batch 349 d_loss: 0.4580821990966797
# Batch 349 g_loss: [array(0.4580822, dtype=float32), array(0.4580822, dtype=float32), array(0.4580822, dtype=float32)]
# Batch 350 d_loss: 0.45808303356170654
# Batch 350 g_loss: [array(0.45808303, dtype=float32), array(0.45808303, dtype=float32), array(0.45808303, dtype=float32)]
# Batch 351 d_loss: 0.4580693244934082
# Batch 351 g_loss: [array(0.45806932, dtype=float32), array(0.45806932, dtype=float32), array(0.45806932, dtype=float32)]
# Batch 352 d_loss: 0.4580927789211273
# Batch 352 g_loss: [array(0.45809278, dtype=float32), array(0.45809278, dtype=float32), array(0.45809278, dtype=float32)]
# Batch 353 d_loss: 0.4581012725830078
# Batch 353 g_loss: [array(0.45810127, dtype=float32), array(0.45810127, dtype=float32), array(0.45810127, dtype=float32)]
# Batch 354 d_loss: 0.4580819606781006
# Batch 354 g_loss: [array(0.45808196, dtype=float32), array(0.45808196, dtype=float32), array(0.45808196, dtype=float32)]
# Batch 355 d_loss: 0.458061158657074
# Batch 355 g_loss: [array(0.45806116, dtype=float32), array(0.45806116, dtype=float32), array(0.45806116, dtype=float32)]
# Batch 356 d_loss: 0.4580417275428772
# Batch 356 g_loss: [array(0.45804173, dtype=float32), array(0.45804173, dtype=float32), array(0.45804173, dtype=float32)]
# Batch 357 d_loss: 0.458048552274704
# Batch 357 g_loss: [array(0.45804855, dtype=float32), array(0.45804855, dtype=float32), array(0.45804855, dtype=float32)]
# Batch 358 d_loss: 0.45802220702171326
# Batch 358 g_loss: [array(0.4580222, dtype=float32), array(0.4580222, dtype=float32), array(0.4580222, dtype=float32)]
# Batch 359 d_loss: 0.4580221474170685
# Batch 359 g_loss: [array(0.45802215, dtype=float32), array(0.45802215, dtype=float32), array(0.45802215, dtype=float32)]
# Batch 360 d_loss: 0.4579983949661255
# Batch 360 g_loss: [array(0.4579984, dtype=float32), array(0.4579984, dtype=float32), array(0.4579984, dtype=float32)]
# Batch 361 d_loss: 0.45796075463294983
# Batch 361 g_loss: [array(0.45796075, dtype=float32), array(0.45796075, dtype=float32), array(0.45796075, dtype=float32)]
# Batch 362 d_loss: 0.4579840302467346
# Batch 362 g_loss: [array(0.45798403, dtype=float32), array(0.45798403, dtype=float32), array(0.45798403, dtype=float32)]
# Batch 363 d_loss: 0.45795953273773193
# Batch 363 g_loss: [array(0.45795953, dtype=float32), array(0.45795953, dtype=float32), array(0.45795953, dtype=float32)]
# Batch 364 d_loss: 0.4579548239707947
# Batch 364 g_loss: [array(0.45795482, dtype=float32), array(0.45795482, dtype=float32), array(0.45795482, dtype=float32)]
# Batch 365 d_loss: 0.45791158080101013
# Batch 365 g_loss: [array(0.45791158, dtype=float32), array(0.45791158, dtype=float32), array(0.45791158, dtype=float32)]
# Batch 366 d_loss: 0.4579138159751892
# Batch 366 g_loss: [array(0.45791382, dtype=float32), array(0.45791382, dtype=float32), array(0.45791382, dtype=float32)]
# Batch 367 d_loss: 0.4579412639141083
# Batch 367 g_loss: [array(0.45794126, dtype=float32), array(0.45794126, dtype=float32), array(0.45794126, dtype=float32)]
# Batch 368 d_loss: 0.457917720079422
# Batch 368 g_loss: [array(0.45791772, dtype=float32), array(0.45791772, dtype=float32), array(0.45791772, dtype=float32)]
# Batch 369 d_loss: 0.45789968967437744
# Batch 369 g_loss: [array(0.4578997, dtype=float32), array(0.4578997, dtype=float32), array(0.4578997, dtype=float32)]
# Batch 370 d_loss: 0.4579342305660248
# Batch 370 g_loss: [array(0.45793423, dtype=float32), array(0.45793423, dtype=float32), array(0.45793423, dtype=float32)]
# Batch 371 d_loss: 0.4580130875110626
# Batch 371 g_loss: [array(0.4580131, dtype=float32), array(0.4580131, dtype=float32), array(0.4580131, dtype=float32)]
# Batch 372 d_loss: 0.4580661654472351
# Batch 372 g_loss: [array(0.45806617, dtype=float32), array(0.45806617, dtype=float32), array(0.45806617, dtype=float32)]
# Batch 373 d_loss: 0.4580569565296173
# Batch 373 g_loss: [array(0.45805696, dtype=float32), array(0.45805696, dtype=float32), array(0.45805696, dtype=float32)]
